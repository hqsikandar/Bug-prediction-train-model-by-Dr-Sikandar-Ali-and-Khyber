# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split

from sklearn.metrics import roc_curve,f1_score,roc_auc_score
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import accuracy_score
from imblearn.over_sampling import SMOTE
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
#First project: importing the dataset
url_v3='/content/drive/MyDrive/ApacheProjectDataset/apache-ant-1.3.csv'
dataset_v3 = pd.read_csv(url_v3)

# %%
url_v4='/content/drive/MyDrive/ApacheProjectDataset/apache-ant-1.4.csv'
dataset_v4 = pd.read_csv(url_v4)

# %%
url_v5='/content/drive/MyDrive/ApacheProjectDataset/apache-ant-1.5.csv'
dataset_v5 = pd.read_csv(url_v5)

# %%
url_v6='/content/drive/MyDrive/ApacheProjectDataset/apache-ant-1.6.csv'
dataset_v6 = pd.read_csv(url_v6)

# %%
url_v7='/content/drive/MyDrive/ApacheProjectDataset/apache-ant-1.7.csv'
dataset_v7 = pd.read_csv(url_v7)

# %%
pdList=[dataset_v3 , dataset_v4 , dataset_v5 , dataset_v6,dataset_v7]
dataset_AntProject = pd.concat(pdList,ignore_index=True)

# %% [markdown]
# **Second Project**

# %%
url_v_camel_v1='/content/drive/MyDrive/ApacheProjectDataset/apache-camel-1.0.csv'
dataset_camel_v1 = pd.read_csv(url_v_camel_v1)

# %%
url_camel_v2='/content/drive/MyDrive/ApacheProjectDataset/apache-camel-1.2.csv'
dataset_camel_v2 = pd.read_csv(url_camel_v2)

# %%
url_camel_v4='/content/drive/MyDrive/ApacheProjectDataset/apache-camel-1.4.csv'
dataset_camel_v4 = pd.read_csv(url_camel_v4)

# %%
url_camel_v6='/content/drive/MyDrive/ApacheProjectDataset/apache-camel-1.6.csv'
dataset_camel_v6 = pd.read_csv(url_camel_v6)

# %%
pdList=[dataset_camel_v1, dataset_camel_v2,dataset_camel_v4, dataset_camel_v6]
dataset_CamelProject = pd.concat(pdList,ignore_index=True)
#dataset_CamelProject

# %% [markdown]
# **Third Project**

# %%
url_forrest_v7='/content/drive/MyDrive/ApacheProjectDataset/apache-forrest-0.7.csv'
dataset_forrest_v7 = pd.read_csv(url_forrest_v7)

# %%
url_forrest_v8='/content/drive/MyDrive/ApacheProjectDataset/apache-forrest-0.8.csv'
dataset_forrest_v8 = pd.read_csv(url_forrest_v8)

# %%
pdList=[dataset_forrest_v7,dataset_forrest_v8]
dataset_ForrestProject = pd.concat(pdList,ignore_index=True)
#dataset_ForrestProject

# %%
url_ivy_v2='/content/drive/MyDrive/ApacheProjectDataset/apache-ivy-2.csv'
dataset_ivy_v2 = pd.read_csv(url_ivy_v2)
#dataset_ivy_v2

# %%
url_log4j_v0='/content/drive/MyDrive/ApacheProjectDataset/apache-log4j-1.0.csv'
dataset_log4j_v0 = pd.read_csv(url_log4j_v0)

# %%
url_log4j_v1='/content/drive/MyDrive/ApacheProjectDataset/apache-log4j-1.1.csv'
dataset_log4j_v1 = pd.read_csv(url_log4j_v1)

# %%
url_log4j_v2='/content/drive/MyDrive/ApacheProjectDataset/apache-log4j-1.2.csv'
dataset_log4j_v2 = pd.read_csv(url_log4j_v2)

# %%
pdList=[dataset_log4j_v0,dataset_log4j_v1,dataset_log4j_v2]
dataset_Log4jProject = pd.concat(pdList,ignore_index=True)
#dataset_Log4jProject

# %%
url_lucene_v0='/content/drive/MyDrive/ApacheProjectDataset/apache-lucene-2.0.csv'
dataset_lucene_v0 = pd.read_csv(url_lucene_v0)

# %%
url_lucene_v2='/content/drive/MyDrive/ApacheProjectDataset/apache-lucene-2.2.csv'
dataset_lucene_v2 = pd.read_csv(url_lucene_v2)

# %%
url_lucene_v4='/content/drive/MyDrive/ApacheProjectDataset/apache-lucene-2.4.csv'
dataset_lucene_v4 = pd.read_csv(url_lucene_v4)

# %%
pdList=[dataset_lucene_v0,dataset_lucene_v2,dataset_lucene_v4]
dataset_LuceneProject = pd.concat(pdList,ignore_index=True)
#dataset_LuceneProject

# %%
url_pbeans_v0='/content/drive/MyDrive/ApacheProjectDataset/apache-pbeans-1.0.csv'
dataset_pbeans_v0 = pd.read_csv(url_pbeans_v0)

# %%
url_pbeans_v2='/content/drive/MyDrive/ApacheProjectDataset/apache-pbeans-2.0.csv'
dataset_pbeans_v2 = pd.read_csv(url_pbeans_v2)

# %%
pdList=[dataset_pbeans_v0,dataset_pbeans_v2]
dataset_PbeansProject = pd.concat(pdList,ignore_index=True)
#dataset_PbeansProject

# %%
url_poi_v5='/content/drive/MyDrive/ApacheProjectDataset/apache-poi-1.5.csv'
dataset_poi_v5 = pd.read_csv(url_poi_v5)

# %%
url_poi_v2_0='/content/drive/MyDrive/ApacheProjectDataset/apache-poi-2.0.csv'
dataset_poi_v2_0 = pd.read_csv(url_poi_v2_0)

# %%
url_poi_v5_1='/content/drive/MyDrive/ApacheProjectDataset/apache-poi-2.5.1.csv'
dataset_poi_v5_1 = pd.read_csv(url_poi_v5_1)

# %%
url_poi_v3_0='/content/drive/MyDrive/ApacheProjectDataset/apache-poi-3.0.csv'
dataset_poi_v3_0 = pd.read_csv(url_poi_v3_0)

# %%
pdList=[dataset_poi_v5,dataset_poi_v2_0,dataset_poi_v5_1,dataset_poi_v3_0]
dataset_PoiProject = pd.concat(pdList,ignore_index=True)
#dataset_PoiProject

# %%
url_synapse_v0='/content/drive/MyDrive/ApacheProjectDataset/apache-synapse-1.0.csv'
dataset_synapse_v0 = pd.read_csv(url_synapse_v0)

# %%
url_synapse_v1='/content/drive/MyDrive/ApacheProjectDataset/apache-synapse-1.1.csv'
dataset_synapse_v1 = pd.read_csv(url_synapse_v1)

# %%
url_synapse_v2='/content/drive/MyDrive/ApacheProjectDataset/apache-synapse-1.2.csv'
dataset_synapse_v2 = pd.read_csv(url_synapse_v2)

# %%
pdList=[dataset_synapse_v0,dataset_synapse_v1,dataset_synapse_v2]
dataset_SynapseProject = pd.concat(pdList,ignore_index=True)
#dataset_SynapseProject

# %%
url_tomcat_v6='/content/drive/MyDrive/ApacheProjectDataset/apache-tomcat-6.csv'
dataset_tomcat_v6 = pd.read_csv(url_tomcat_v6)
#dataset_tomcat_v6

# %%
url_velocity_v5='/content/drive/MyDrive/ApacheProjectDataset/apache-velocity.1.5.csv'
dataset_velocity_v5 = pd.read_csv(url_velocity_v5)

# %%
url_velocity_v4='/content/drive/MyDrive/ApacheProjectDataset/apache-velocity-1.4.csv'
dataset_velocity_v4 = pd.read_csv(url_velocity_v4)

# %%
url_velocity_v6_1='/content/drive/MyDrive/ApacheProjectDataset/apache-velocity-1.6.1.csv'
dataset_velocity_v6_1 = pd.read_csv(url_velocity_v6_1)

# %%
pdList=[dataset_velocity_v5,dataset_velocity_v4,dataset_velocity_v6_1]
dataset_VelocityProject = pd.concat(pdList,ignore_index=True)
#dataset_VelocityProject

# %%
url_xalan_v4='/content/drive/MyDrive/ApacheProjectDataset/apache-xalan-2.4.csv'
dataset_xalan_v4 = pd.read_csv(url_xalan_v4)

# %%
url_xalan_v5='/content/drive/MyDrive/ApacheProjectDataset/apache-xalan-2.5.csv'
dataset_xalan_v5 = pd.read_csv(url_xalan_v5)

# %%
url_xalan_v6='/content/drive/MyDrive/ApacheProjectDataset/apache-xalan-2.6.csv'
dataset_xalan_v6 = pd.read_csv(url_xalan_v6)

# %%
url_xalan_v7='/content/drive/MyDrive/ApacheProjectDataset/apache-xalan-2.7.csv'
dataset_xalan_v7 = pd.read_csv(url_xalan_v7)

# %%
pdList=[dataset_xalan_v4,dataset_xalan_v5,dataset_xalan_v6,dataset_xalan_v7]
dataset_XalanProject = pd.concat(pdList,ignore_index=True)
#dataset_XalanProject

# %%
url_xerces_v2='/content/drive/MyDrive/ApacheProjectDataset/apache-xerces-1.2.csv'
dataset_xerces_v2 = pd.read_csv(url_xerces_v2)

# %%
url_xerces_v3='/content/drive/MyDrive/ApacheProjectDataset/apache-xerces-1.3.csv'
dataset_xerces_v3 = pd.read_csv(url_xerces_v3)

# %%
url_xerces_v4_4='/content/drive/MyDrive/ApacheProjectDataset/apache-xerces-1.4.4.csv'
dataset_xerces_v4_4 = pd.read_csv(url_xerces_v4_4)

# %%
pdList=[dataset_xerces_v2,dataset_xerces_v3,dataset_xerces_v4_4]
dataset_XercesProject = pd.concat(pdList,ignore_index=True)
#dataset_XercesProject

# %%
url_jEdit_v3_2='/content/drive/MyDrive/ApacheProjectDataset/jEdit-3.2.csv'
dataset_jEdit_v3_2 = pd.read_csv(url_jEdit_v3_2)

# %%
url_jEdit_v0='/content/drive/MyDrive/ApacheProjectDataset/jEdit-4.0.csv'
dataset_jEdit_v0 = pd.read_csv(url_jEdit_v0)

# %%
url_jEdit_v1='/content/drive/MyDrive/ApacheProjectDataset/jEdit-4.1.csv'
dataset_jEdit_v1 = pd.read_csv(url_jEdit_v1)

# %%
url_jEdit_v2='/content/drive/MyDrive/ApacheProjectDataset/jEdit-4.2.csv'
dataset_jEdit_v2 = pd.read_csv(url_jEdit_v2)

# %%
url_jEdit_v3='/content/drive/MyDrive/ApacheProjectDataset/jEdit-4.3.csv'
dataset_jEdit_v3 = pd.read_csv(url_jEdit_v3)

# %%
pdList=[dataset_jEdit_v3_2,dataset_jEdit_v0, dataset_jEdit_v1, dataset_jEdit_v2, dataset_jEdit_v3]
dataset_JEditProject = pd.concat(pdList,ignore_index=True)
#dataset_JEditProject

# %%
pdList=[dataset_v3 , dataset_v4 , dataset_v5 , dataset_v6,dataset_v7,dataset_camel_v1, dataset_camel_v2,
      dataset_camel_v4, dataset_camel_v6,dataset_forrest_v7,dataset_forrest_v8, dataset_ivy_v2, dataset_log4j_v0, dataset_log4j_v1,
     dataset_log4j_v2,dataset_lucene_v0, dataset_lucene_v2, dataset_lucene_v4, dataset_pbeans_v0, dataset_pbeans_v2,
       dataset_poi_v5, dataset_poi_v2_0, dataset_poi_v5_1,dataset_poi_v3_0,dataset_synapse_v0, dataset_synapse_v1, dataset_synapse_v2,
       dataset_tomcat_v6,dataset_velocity_v5, dataset_velocity_v4, dataset_velocity_v6_1, dataset_xalan_v4, dataset_xalan_v5,
       dataset_xalan_v6, dataset_xalan_v7,dataset_xerces_v2, dataset_xerces_v3, dataset_xerces_v4_4,dataset_jEdit_v3_2,
       dataset_jEdit_v0, dataset_jEdit_v1, dataset_jEdit_v2, dataset_jEdit_v3]
dataset = pd.concat(pdList,ignore_index=True)

dataset
# Out:
#       project-name version                                             name  \
# 0              ant     1.3          org.apache.tools.ant.taskdefs.ExecuteOn
# 1              ant     1.3               org.apache.tools.ant.DefaultLogger
# 2              ant     1.3   org.apache.tools.ant.taskdefs.TaskOutputStream
# 3              ant     1.3                org.apache.tools.ant.taskdefs.Cvs
# 4              ant     1.3           org.apache.tools.ant.taskdefs.Copyfile
# ...            ...     ...                                              ...
# 16252        jEdit     4.3      org.gjt.sp.jedit.input.TextAreaInputHandler
# 16253        jEdit     4.3                   org.gjt.sp.jedit.msg.VFSUpdate
# 16254        jEdit     4.3            org.gjt.sp.jedit.msg.PositionChanging
# 16255        jEdit     4.3  org.gjt.sp.jedit.bsh.reflect.ReflectManagerImpl
# 16256        jEdit     4.3        org.gjt.sp.jedit.search.HyperSearchResult
#
# ...

# %%
dataset.head()
#dataset_AntProject.head()
# Out:
#   project-name version                                            name  wmc  \
# 0          ant     1.3         org.apache.tools.ant.taskdefs.ExecuteOn   11
# 1          ant     1.3              org.apache.tools.ant.DefaultLogger   14
# 2          ant     1.3  org.apache.tools.ant.taskdefs.TaskOutputStream    3
# 3          ant     1.3               org.apache.tools.ant.taskdefs.Cvs   12
# 4          ant     1.3          org.apache.tools.ant.taskdefs.Copyfile    6
#
#    dit  noc  cbo  rfc  lcom  ca  ...  ostrand  scattering  intensity  ana  \
# 0    4    2   14   42    29   2  ...      2.0        10.0       0.37  2.0
# 1    1    1    8   32    49   4  ...      2.0        29.0       0.00  1.0
# 2    2    0    1    9     0   0  ...      3.0        25.0       0.64  1.0
# 3    3    0   12   37    32   0  ...      1.0        12.0       0.35  3.0
# 4    3    0    4   21     1   0  ...      2.0        24.0       0.35  1.0
#
#    acm  arl  acpd  bug  is-buggy  is-buggy-boolean
# ...

# %%
#dataset['is-buggy'].value_counts()
dataset['is-buggy'].value_counts()
# Out:
# 0    10637
# 1     5620
# Name: is-buggy, dtype: int64

# %%
#dataset['is-buggy'].describe()
dataset['is-buggy'].describe()
# Out:
# count    16257.000000
# mean         0.345697
# std          0.475610
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000
# Name: is-buggy, dtype: float64

# %%
#list(dataset.columns)
list(dataset.columns)
#list(dataset.columns.values)
# Out:
# ['project-name',
#  'version',
#  'name',
#  'wmc',
#  'dit',
#  'noc',
#  'cbo',
#  'rfc',
#  'lcom',
#  'ca',
#  'ce',
#  'npm',
#  'lcom3',
#  'loc',
#  'dam',
#  'moa',
#  'mfa',
#  'cam',
#  'ic',
#  'cbm',
#  'amc',
#  'max_cc',
#  'avg_cc',
#  'fi-changes',
#  'ostrand',
#  'scattering',
#  'intensity',
#  'ana',
#  'acm',
#  'arl',
#  'acpd',
#  'bug',
#  'is-buggy',
#  'is-buggy-boolean']

# %%
#dataset.info()

# %%
#dataset.shape
dataset.shape
# Out:
# (16257, 34)

# %%
dataset.drop(['project-name','version','name','is-buggy-boolean'],axis=1,inplace=True)
dataset.head()
# Out:
#    wmc  dit  noc  cbo  rfc  lcom  ca  ce  npm     lcom3  ...  fi-changes  \
# 0   11    4    2   14   42    29   2  12    5  0.725000  ...        34.0
# 1   14    1    1    8   32    49   4   4   12  0.835165  ...        71.0
# 2    3    2    0    1    9     0   0   1    1  0.000000  ...        53.0
# 3   12    3    0   12   37    32   0  12   12  0.858586  ...        36.0
# 4    6    3    0    4   21     1   0   4    6  0.700000  ...        53.0
#
#    ostrand  scattering  intensity  ana  acm  arl  acpd  bug  is-buggy
# 0      2.0        10.0       0.37  2.0  4.0  2.0  1.73    0         0
# 1      2.0        29.0       0.00  1.0  7.0  5.0  2.68    2         1
# 2      3.0        25.0       0.64  1.0  9.0  1.0  5.69    0         0
# 3      1.0        12.0       0.35  3.0  3.0  1.0  1.41    0         0
# 4      2.0        24.0       0.35  1.0  9.0  4.0  1.17    0         0
#
# [5 rows x 30 columns]

# %%
#dataset=dataset.isnull().value_counts()
#dataset=dataset.isnull().values.any()
#pd.isnull(dataset).sum().sum()
#pd.isnull(dataset)
#dataset.isnull()

# %%
#How to get column names in Pandas dataframe  note: it does not work in colab notebook but works in
#len(dataset.columns)

# %%
dataset.dtypes
# Out:
# wmc             int64
# dit             int64
# noc             int64
# cbo             int64
# rfc             int64
# lcom            int64
# ca              int64
# ce              int64
# npm             int64
# lcom3         float64
# loc             int64
# dam           float64
# moa             int64
# mfa           float64
# cam           float64
# ic              int64
# cbm             int64
# amc           float64
# max_cc          int64
# avg_cc        float64
# fi-changes    float64
# ostrand       float64
# scattering    float64
# intensity     float64
# ana           float64
# acm           float64
# arl           float64
# acpd          float64
# bug             int64
# is-buggy        int64
# dtype: object

# %%
#seaborn.countplot() method is used to Show the counts of observations in each categorical bin using bars.
#sns.countplot(x = 'is-buggy',hue = 'is-buggy', data = dataset)
sns.countplot(x = 'is-buggy',hue = 'is-buggy', data = dataset)
# Out:
# <Axes: xlabel='is-buggy', ylabel='count'>

# %%
# Splitting the dataset into the Training set and Test set. ...

#Let's drop the target coloumn before we do train test split
#X = dataset.drop('is-buggy',axis=1).values
X =dataset.iloc[:, :-1].values
X
# Out:
# array([[11.  ,  4.  ,  2.  , ...,  2.  ,  1.73,  0.  ],
#        [14.  ,  1.  ,  1.  , ...,  5.  ,  2.68,  2.  ],
#        [ 3.  ,  2.  ,  0.  , ...,  1.  ,  5.69,  0.  ],
#        ...,
#        [ 3.  ,  3.  ,  1.  , ...,  3.  ,  4.87,  0.  ],
#        [ 2.  ,  2.  ,  0.  , ...,  2.  ,  6.64,  0.  ],
#        [10.  ,  1.  ,  0.  , ...,  5.  ,  7.17,  0.  ]])

# %%
X.dtype
# Out:
# dtype('float64')

# %%
#y = dataset['is-buggy']
y = dataset.iloc[:, -1].values.astype(np.float64)
y
# Out:
# array([0., 1., 0., ..., 0., 0., 0.])

# %%
dataset['is-buggy'].value_counts()
# Out:
# 0    10637
# 1     5620
# Name: is-buggy, dtype: int64

# %%
# Class count of buggy or not buggy
count_class_0, count_class_1 = dataset['is-buggy'].value_counts()

# Divide by class
df_none_buggy_0 = dataset[dataset['is-buggy'] == 0]
df_buggy_1 =dataset[dataset['is-buggy'] == 1]

# %%
count_class_0
# Out:
# 10637

# %%
count_class_1
# Out:
# 5620

# %%
df_none_buggy_0.head(2)
# Out:
#    wmc  dit  noc  cbo  rfc  lcom  ca  ce  npm  lcom3  ...  fi-changes  \
# 0   11    4    2   14   42    29   2  12    5  0.725  ...        34.0
# 2    3    2    0    1    9     0   0   1    1  0.000  ...        53.0
#
#    ostrand  scattering  intensity  ana  acm  arl  acpd  bug  is-buggy
# 0      2.0        10.0       0.37  2.0  4.0  2.0  1.73    0         0
# 2      3.0        25.0       0.64  1.0  9.0  1.0  5.69    0         0
#
# [2 rows x 30 columns]

# %%
df_buggy_1.head(2)
# Out:
#    wmc  dit  noc  cbo  rfc  lcom  ca  ce  npm     lcom3  ...  fi-changes  \
# 1   14    1    1    8   32    49   4   4   12  0.835165  ...        71.0
# 9   17    3    0   10   55    76   5   6   11  0.593750  ...        11.0
#
#    ostrand  scattering  intensity  ana  acm  arl  acpd  bug  is-buggy
# 1      2.0        29.0       0.00  1.0  7.0  5.0  2.68    2         1
# 9      1.0        24.0       6.93  3.0  4.0  4.0  1.97    1         1
#
# [2 rows x 30 columns]

# %%
smote = SMOTE(sampling_strategy='minority')
X_sm, y_sm = smote.fit_resample(X,y)

# %%
from collections import Counter
print("After SMOTE :" , Counter(y_sm))
# Out:
# After SMOTE : Counter({0.0: 10637, 1.0: 10637})

# %%
X_train, X_test, y_train, y_test = train_test_split(X_sm, y_sm, test_size=0.30, random_state=42,)
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.50, random_state=42,)
#,shuffle=False

# %%
#feature Scaling
from sklearn.preprocessing import StandardScaler
St_Sc= StandardScaler()
Scaled_X_train= St_Sc.fit_transform(X_train)
Scaled_X_test= St_Sc.transform(X_test)

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(Scaled_X_train, y_train)
knn.score(Scaled_X_test, y_test)
knn_y_predicted=knn.predict(Scaled_X_test)
print('Test Accuracy', knn.score(Scaled_X_test,y_test));
test_accuracy=accuracy_score(y_test,knn_y_predicted);
print("testing accuracy2 ",test_accuracy);
print(f'Train accuracy: {knn.score(Scaled_X_train,y_train)}')
print("balanced_accuracy:",metrics.balanced_accuracy_score(y_test,knn_y_predicted))
# Out:
# Test Accuracy 0.8622904590318032
# testing accuracy2  0.8622904590318032
# Train accuracy: 0.9335840440534551
# balanced_accuracy: 0.8627255039463191

# %%
cnf_matrix = metrics.confusion_matrix(y_test,knn_y_predicted)
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("bottom")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual values')
plt.xlabel('Predicted values')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted values')

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,knn_y_predicted))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.84      0.86      3255
#          1.0       0.84      0.88      0.86      3128
#
#     accuracy                           0.86      6383
#    macro avg       0.86      0.86      0.86      6383
# weighted avg       0.86      0.86      0.86      6383

# %%
print("test Accuracy:",accuracy_score(y_test,knn_y_predicted))
print(f'Train accuracy: {knn.score(Scaled_X_train,y_train)}')
print("Precision:",metrics.precision_score(y_test,knn_y_predicted))
print("Recall:",metrics.recall_score(y_test,knn_y_predicted))
print("F1 Score:",metrics.f1_score(y_test,knn_y_predicted))
print("balanced_accuracy:",metrics.balanced_accuracy_score(y_test,knn_y_predicted))
# balanced_accuracy
# Out:
# test Accuracy: 0.8622904590318032
# Train accuracy: 0.9335840440534551
# Precision: 0.8423135464231355
# Recall: 0.8845907928388747
# F1 Score: 0.8629346639638235
# balanced_accuracy: 0.8627255039463191

# %%
lr = LogisticRegression(random_state = 42)
lr.fit(Scaled_X_train, y_train)
lr.score(Scaled_X_test, y_test)
lr_y_predicted=lr.predict(Scaled_X_test)
print('Test Accuracy', lr.score(Scaled_X_test,y_test));
test_accuracy=accuracy_score(y_test,lr_y_predicted);
print("testing accuracy2 ",test_accuracy);
print(f'Train accuracy: {lr.score(Scaled_X_train,y_train)}')
print("balanced_accuracy:",metrics.balanced_accuracy_score(y_test,lr_y_predicted))
# Out:
# Test Accuracy 0.9963966786777377
# testing accuracy2  0.9963966786777377
# Train accuracy: 0.9967765764555772
# balanced_accuracy: 0.9964420270211871

# %%
cnf_matrix = metrics.confusion_matrix(y_test,lr_y_predicted)
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("bottom")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual values')
plt.xlabel('Predicted values')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted values')

# %%
lr_y_predicted
# Out:
# array([1., 0., 0., ..., 0., 0., 0.])

# %%
print("test Accuracy:",accuracy_score(y_test,lr_y_predicted))
print(f'Train accuracy: {lr.score(Scaled_X_train,y_train)}')
print("Precision:",metrics.precision_score(y_test,lr_y_predicted))
print("Recall:",metrics.recall_score(y_test,lr_y_predicted))
print("F1 Score:",metrics.f1_score(y_test,lr_y_predicted))
print("balanced_accuracy:",metrics.balanced_accuracy_score(y_test,lr_y_predicted))
# balanced_accuracy
# Out:
# test Accuracy: 0.9963966786777377
# Train accuracy: 0.9967765764555772
# Precision: 0.9939548202354438
# Recall: 0.9987212276214834
# F1 Score: 0.9963323233933982
# balanced_accuracy: 0.9964420270211871

# %%
#svm = SVC(C=100, kernel='rbf', degree=3,probability=True,gamma=1)
svm = SVC(C=1, kernel='linear', degree=3,probability=True)
svm.fit(Scaled_X_train, y_train)
svm.score(Scaled_X_test, y_test)
svm_y_predicted=svm.predict(Scaled_X_test)
training_accuracy=accuracy_score(y_test,svm_y_predicted);
print("training accuracy ",training_accuracy);
print('Test Accuracy Score', svm.score(Scaled_X_test,y_test));
print("balanced_accuracy:",metrics.balanced_accuracy_score(y_test,svm_y_predicted))
# Out:
# training accuracy  0.9971800093999686
# Test Accuracy Score 0.9971800093999686
# balanced_accuracy: 0.9972350230414746

# %%
svm_y_predicted
# Out:
# array([1., 0., 0., ..., 0., 0., 0.])

# %%
cnf_matrix = metrics.confusion_matrix(y_test,svm_y_predicted)
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("bottom")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual values')
plt.xlabel('Predicted values')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted values')

# %%
print("Testing Accuracy:",accuracy_score(y_test,svm_y_predicted))
print("Precision:",metrics.precision_score(y_test,svm_y_predicted))
print("Recall:",metrics.recall_score(y_test,svm_y_predicted))
print("F1 Score:",metrics.f1_score(y_test,svm_y_predicted))
print("balanced_accuracy:",metrics.balanced_accuracy_score(y_test,svm_y_predicted))
# balanced_accuracy
# Out:
# Testing Accuracy: 0.9971800093999686
# Precision: 0.9942784488239034
# Recall: 1.0
# F1 Score: 0.9971310168951227
# balanced_accuracy: 0.9972350230414746

# %%
# rf = RandomForestClassifier(max_features=0.01,n_estimators=500)
rf=RandomForestClassifier(max_features=0.4, n_estimators = 1000,n_jobs = -1,random_state =1)
#rf=RandomForestClassifier(max_features=0.02, n_estimators = 10,n_jobs = -1,random_state =1,oob_score=True)
rf.fit(Scaled_X_train, y_train)
rf.score(Scaled_X_test, y_test)
rf_y_predicted=rf.predict(Scaled_X_test)
test_accuracy=accuracy_score(y_test,rf_y_predicted);
print("test_accuracy ",test_accuracy);
print('training accuracy',rf.score(Scaled_X_train,y_train))
print('Test Accuracy ', rf.score(Scaled_X_test,y_test));
print("balanced_accuracy:",metrics.balanced_accuracy_score(y_test,rf_y_predicted))
# Out:
# test_accuracy  0.9973366755444149
# training accuracy 1.0
# Test Accuracy  0.9973366755444149
# balanced_accuracy: 0.9973886328725039

# %%
cnf_matrix = metrics.confusion_matrix(y_test,rf_y_predicted)
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("bottom")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual values')
plt.xlabel('Predicted values')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted values')

# %%
print("Testing Accuracy:",metrics.accuracy_score(y_test,rf_y_predicted))
print("Precision:",metrics.precision_score(y_test,rf_y_predicted))
print("Recall:",metrics.recall_score(y_test,rf_y_predicted))
print("F1 Score:",metrics.f1_score(y_test,rf_y_predicted))
print("balanced_accuracy:",metrics.balanced_accuracy_score(y_test,rf_y_predicted))
# balanced_accuracy
# Out:
# Testing Accuracy: 0.9973366755444149
# Precision: 0.9945945945945946
# Recall: 1.0
# F1 Score: 0.997289972899729
# balanced_accuracy: 0.9973886328725039

# %%
nb = GaussianNB()
nb.fit(Scaled_X_train, y_train)
nb.score(Scaled_X_test, y_test)
nb_y_predicted=nb.predict(Scaled_X_test)
testing_accuracy=accuracy_score(y_test,nb_y_predicted);
print("testing accuracy ",testing_accuracy);
print("training accuracy",nb.score(Scaled_X_train,y_train))
print('Test Accuracy Score', nb.score(Scaled_X_test,y_test));
print("balanced_accuracy:",metrics.balanced_accuracy_score(y_test,nb_y_predicted))
# Out:
# testing accuracy  0.8196772677424409
# training accuracy 0.8078033711637902
# Test Accuracy Score 0.8196772677424409
# balanced_accuracy: 0.8174635422191316

# %%
cnf_matrix = metrics.confusion_matrix(y_test,nb_y_predicted)
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("bottom")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual values')
plt.xlabel('Predicted values')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted values')

# %%
print("Testing Accuracy:",metrics.accuracy_score(y_test,nb_y_predicted))
print("Precision:",metrics.precision_score(y_test,nb_y_predicted))
print("Recall:",metrics.recall_score(y_test,nb_y_predicted))
print("F1 Score:",metrics.f1_score(y_test,nb_y_predicted))
print("balanced_accuracy:",metrics.balanced_accuracy_score(y_test,nb_y_predicted))
# balanced_accuracy
# Out:
# Testing Accuracy: 0.8196772677424409
# Precision: 0.9049569848422777
# Recall: 0.7062020460358056
# F1 Score: 0.7933201652002154
# balanced_accuracy: 0.8174635422191316

# %%
r_probs = [0 for _ in range(len(y_test))]
lr_probs = lr.predict_proba(Scaled_X_test)
svm_probs = svm.predict_proba(Scaled_X_test)
rf_probs=rf.predict_proba(Scaled_X_test)
nb_probs=nb.predict_proba(Scaled_X_test)
knn_probs=knn.predict_proba(Scaled_X_test)

# %%
lr_probs = lr_probs[:, 1]
svm_probs = svm_probs[:, 1]
rf_probs = rf_probs[:, 1]
nb_probs = nb_probs[:, 1]
knn_probs = knn_probs[:, 1]

# %%
r_auc = roc_auc_score(y_test, r_probs)
lr_auc = roc_auc_score(y_test, lr_probs)
svm_auc = roc_auc_score(y_test, svm_probs)
rf_auc = roc_auc_score(y_test, rf_probs)
nb_auc = roc_auc_score(y_test, nb_probs)
knn_auc = roc_auc_score(y_test, knn_probs)

# %%
print('Random (chance) Prediction: AUROC = %.3f' % (r_auc))
print('Logistic regression: AUROC = %.3f' % (lr_auc))
print('Support victor machine: AUROC = %.3f' % (svm_auc))
print('Random Forest: AUROC = %.3f' % (rf_auc))
print('Naive Bayes: AUROC = %.3f' % (nb_auc))
print('K Nearest Neighbor: AUROC = %.3f' % (knn_auc))
# Out:
# Random (chance) Prediction: AUROC = 0.500
# Logistic regression: AUROC = 0.996
# Support victor machine: AUROC = 0.996
# Random Forest: AUROC = 1.000
# Naive Bayes: AUROC = 0.948
# K Nearest Neighbor: AUROC = 0.923

# %%
r_fpr, r_tpr, _ = roc_curve(y_test, r_probs)
lr_fpr, lr_tpr, _ = roc_curve(y_test, lr_probs)
svm_fpr, svm_tpr, _ = roc_curve(y_test, svm_probs)
rf_fpr, rf_tpr, _ = roc_curve(y_test, rf_probs)
nb_fpr, nb_tpr, _ = roc_curve(y_test, nb_probs)
knn_fpr, knn_tpr, _ = roc_curve(y_test, knn_probs)

# %%
plt.plot(r_fpr, r_tpr, linestyle='--',color="fuchsia", label='Random prediction (AUROC = %0.3f)' % r_auc,linewidth=2.5)
plt.plot(lr_fpr, lr_tpr, linestyle='--',color="green", label='Logistic Regression (AUROC = %0.3f)' % lr_auc,linewidth=2.5)
plt.plot(svm_fpr, svm_tpr, linestyle='--',color="blue", label='Support Vector Machine (AUROC = %0.3f)' % svm_auc,linewidth=2.5)
plt.plot(rf_fpr, rf_tpr, linestyle='--',color="red", label='Random Forest (AUROC = %0.3f)' % rf_auc,linewidth=2.5)
plt.plot(nb_fpr, nb_tpr, linestyle='-', color="red", label='Naive Bayes (AUROC = %0.3f)' % nb_auc,linewidth=2.5)
plt.plot(nb_fpr, nb_tpr, linestyle='--', color="Cyan", label='K Nearest Neighbor (AUROC = %0.3f)' % knn_auc,linewidth=2.5)

#plt.plot(rf_fpr, rf_tpr, marker='.',color="yellow", label='Random Forest (AUROC = %0.3f)' % rf_auc)
#plt.plot(nb_fpr, nb_tpr, marker='.', color="green", label='Naive Bayes (AUROC = %0.3f)' % nb_auc)

# Title
plt.title('ROC curve')
# Axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# Show legend
plt.legend() #
# Show plot
plt.show()

# %%
# predict probabilities
r_probs = [0 for _ in range(len(y_test))]
lr_probs = lr.predict_proba(Scaled_X_test)
svm_probs = svm.predict_proba(Scaled_X_test)
rf_probs=rf.predict_proba(Scaled_X_test)
nb_probs=nb.predict_proba(Scaled_X_test)
knn_probs=knn.predict_proba(Scaled_X_test)

# keep probabilities for the positive outcome only
lr_probs = lr_probs[:, 1]
svm_probs = svm_probs[:, 1]
rf_probs = rf_probs[:, 1]
nb_probs = nb_probs[:, 1]
knn_probs = knn_probs[:, 1]

# predict class values
lr_y_predicted= lr.predict(Scaled_X_test)
lr_precision, lr_recall, _ = precision_recall_curve(y_test, lr_probs)
lr_f1, lr_auc = f1_score(y_test,lr_y_predicted), auc(lr_recall, lr_precision)

rf_y_predicted= rf.predict(Scaled_X_test)
rf_precision, rf_recall, _ = precision_recall_curve(y_test, rf_probs)
rf_f1, rf_auc = f1_score(y_test,rf_y_predicted), auc(rf_recall, rf_precision)

nb_y_predicted= nb.predict(Scaled_X_test)
nb_precision, nb_recall, _ = precision_recall_curve(y_test, nb_probs)
nb_f1, nb_auc = f1_score(y_test,nb_y_predicted), auc(nb_recall, nb_precision)

svm_y_predicted= svm.predict(Scaled_X_test)
svm_precision, svm_recall, _ = precision_recall_curve(y_test, svm_probs)
svm_f1, svm_auc = f1_score(y_test,svm_y_predicted), auc(svm_recall, svm_precision)

knn_y_predicted= knn.predict(Scaled_X_test)
knn_precision, knn_recall, _ = precision_recall_curve(y_test, knn_probs)
knn_f1, knn_auc = f1_score(y_test,knn_y_predicted), auc(knn_recall, knn_precision)

# summarize scores
#print('Logistic Regression: f1=%.3f auc=%.3f' % (lr_f1, lr_auc))
#print('Random Forest: f1=%.3f auc=%.3f' % (rf_f1, rf_auc))
#print('Naive Bayes: f1=%.3f auc=%.3f' % (nb_f1, nb_auc))
#print('Support Vector Machine: f1=%.3f auc=%.3f' % (svm_f1, svm_auc))
#print('K Nearest Neighbor: f1=%.3f auc=%.3f' % (knn_f1, knn_auc))

# plot the precision-recall curves
base_line = len(y_test[y_test==1]) / len(y_test)
plt.plot([0, 1], [base_line, base_line],color='fuchsia', linestyle='--', label='base_line',linewidth=2.5)

base_line = len(y_test[y_test==1]) / len(y_test)
plt.plot(lr_recall, lr_precision, linestyle='--',color='red', label='LR Classifier: f1=%.3f auc=%.3f' % (lr_f1, lr_auc),linewidth=2.5)

base_line = len(y_test[y_test==1]) / len(y_test)
plt.plot(rf_recall, rf_precision,linestyle='--', color='Cyan',label='RF Classifier: f1=%.3f auc=%.3f' % (rf_f1, rf_auc),linewidth=2.5)

base_line = len(y_test[y_test==1]) / len(y_test)
plt.plot(svm_recall, svm_precision, linestyle='--',color='blue', label='SVM Classifier: f1=%.3f auc=%.3f' % (svm_f1, svm_auc),linewidth=2.5)

base_line = len(y_test[y_test==1]) / len(y_test)
plt.plot(nb_recall, nb_precision, linestyle='--', color='green', label='NB Classifier: f1=%.3f auc=%.3f' % (nb_f1, nb_auc),linewidth=2.5)

base_line = len(y_test[y_test==1]) / len(y_test)
plt.plot(knn_recall, knn_precision, linestyle='--',color='yellow', label='KNN Classifier: f1=%.3f auc=%.3f' % (knn_f1, knn_auc),linewidth=2.5)

# axis labels
plt.xlabel('Recall')
plt.ylabel('Precision')
# show the legend
plt.legend()
# show the plot
plt.show()
